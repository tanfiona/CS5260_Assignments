# %%
import os
import re
import pandas as pd

def open_list(txt_file_path:str):
    items = []
    with open(txt_file_path, "r") as f:
        for line in f:
            items.append(str(line.strip()))
    return items

version = 'adamw_lambda_0.001'
txt_file_path = os.path.join('tb_logs',version,'rank_0.log')
open_list(txt_file_path)
# Out:
# ['colossalai - colossalai - 2022-03-28 01:47:26,292 INFO:',
#  '========== Your Config ========',
#  "{'BATCH_SIZE': 128, 'NUM_EPOCHS': 30}",
#  '================================',
#  '',
#  'colossalai - colossalai - 2022-03-28 01:47:26,296 INFO: cuDNN benchmark = True, deterministic = False',
#  'colossalai - colossalai - 2022-03-28 01:47:26,299 WARNING: Initializing an non ZeRO model with optimizer class',
#  'colossalai - colossalai - 2022-03-28 01:47:26,301 WARNING: No PyTorch DDP or gradient handler is set up, please make sure you do not need to all-reduce the gradients after a training step.',
#  'colossalai - colossalai - 2022-03-28 01:47:26,306 INFO: Using LossHook for training, priority = 0',
#  'colossalai - colossalai - 2022-03-28 01:47:26,308 INFO: Using LRSchedulerHook for training, priority = 1',
#  'colossalai - colossalai - 2022-03-28 01:47:26,311 INFO: Using LogMetricByEpochHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:47:26,313 INFO: Using LogMemoryByEpochHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:47:26,315 INFO: Using LogTimingByEpochHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:47:26,317 INFO: Using TensorboardHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:47:26,320 INFO: Lower value means higher priority for calling hook function',
#  'colossalai - colossalai - 2022-03-28 01:47:26,323 INFO: Before-train: GPU: allocated 0.95 MB, max allocated 1.67 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:47:37,179 INFO: [Epoch 0 / Train]: Loss = 0.83319 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:47:37,185 INFO: [Epoch 0 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:47:37,188 INFO: [Epoch 0 / Train]: Train-epoch: last = 10.756 s, mean = 10.756 s | Train-step: last = 0.016703 s, mean = 0.022552 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:47:39,058 INFO: [Epoch 0 / Test]: Loss = 0.71149',
#  'colossalai - colossalai - 2022-03-28 01:47:39,062 INFO: [Epoch 0 / Test]: Test-epoch: last = 1.7007 s, mean = 1.7007 s | Test-step: last = 0.0030634 s, mean = 0.021384 s',
#  'colossalai - colossalai - 2022-03-28 01:47:39,066 INFO: [Epoch 0 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:47:50,375 INFO: [Epoch 1 / Train]: Loss = 0.69125 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:47:50,380 INFO: [Epoch 1 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:47:50,383 INFO: [Epoch 1 / Train]: Train-epoch: last = 11.122 s, mean = 11.122 s | Train-step: last = 0.016561 s, mean = 0.022923 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:47:52,481 INFO: [Epoch 1 / Test]: Loss = 0.64163',
#  'colossalai - colossalai - 2022-03-28 01:47:52,486 INFO: [Epoch 1 / Test]: Test-epoch: last = 1.9329 s, mean = 1.9329 s | Test-step: last = 0.0034683 s, mean = 0.024315 s',
#  'colossalai - colossalai - 2022-03-28 01:47:52,490 INFO: [Epoch 1 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:03,299 INFO: [Epoch 2 / Train]: Loss = 0.62856 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:48:03,304 INFO: [Epoch 2 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:03,307 INFO: [Epoch 2 / Train]: Train-epoch: last = 10.626 s, mean = 10.626 s | Train-step: last = 0.016908 s, mean = 0.022704 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:48:05,180 INFO: [Epoch 2 / Test]: Loss = 0.58556',
#  'colossalai - colossalai - 2022-03-28 01:48:05,186 INFO: [Epoch 2 / Test]: Test-epoch: last = 1.7147 s, mean = 1.7147 s | Test-step: last = 0.0033412 s, mean = 0.021563 s',
#  'colossalai - colossalai - 2022-03-28 01:48:05,190 INFO: [Epoch 2 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:16,255 INFO: [Epoch 3 / Train]: Loss = 0.57791 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:48:16,261 INFO: [Epoch 3 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:16,264 INFO: [Epoch 3 / Train]: Train-epoch: last = 10.872 s, mean = 10.872 s | Train-step: last = 0.017673 s, mean = 0.022725 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:48:18,160 INFO: [Epoch 3 / Test]: Loss = 0.53991',
#  'colossalai - colossalai - 2022-03-28 01:48:18,164 INFO: [Epoch 3 / Test]: Test-epoch: last = 1.723 s, mean = 1.723 s | Test-step: last = 0.004148 s, mean = 0.02167 s',
#  'colossalai - colossalai - 2022-03-28 01:48:18,168 INFO: [Epoch 3 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:29,020 INFO: [Epoch 4 / Train]: Loss = 0.53648 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:48:29,025 INFO: [Epoch 4 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:29,028 INFO: [Epoch 4 / Train]: Train-epoch: last = 10.696 s, mean = 10.696 s | Train-step: last = 0.016206 s, mean = 0.022664 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:48:30,899 INFO: [Epoch 4 / Test]: Loss = 0.50219',
#  'colossalai - colossalai - 2022-03-28 01:48:30,903 INFO: [Epoch 4 / Test]: Test-epoch: last = 1.6999 s, mean = 1.6999 s | Test-step: last = 0.0036666 s, mean = 0.021384 s',
#  'colossalai - colossalai - 2022-03-28 01:48:30,908 INFO: [Epoch 4 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:41,757 INFO: [Epoch 5 / Train]: Loss = 0.50213 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:48:41,763 INFO: [Epoch 5 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:41,767 INFO: [Epoch 5 / Train]: Train-epoch: last = 10.705 s, mean = 10.705 s | Train-step: last = 0.015784 s, mean = 0.022627 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:48:43,623 INFO: [Epoch 5 / Test]: Loss = 0.47138',
#  'colossalai - colossalai - 2022-03-28 01:48:43,627 INFO: [Epoch 5 / Test]: Test-epoch: last = 1.681 s, mean = 1.681 s | Test-step: last = 0.0032196 s, mean = 0.02113 s',
#  'colossalai - colossalai - 2022-03-28 01:48:43,631 INFO: [Epoch 5 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:54,454 INFO: [Epoch 6 / Train]: Loss = 0.47325 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:48:54,460 INFO: [Epoch 6 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:48:54,463 INFO: [Epoch 6 / Train]: Train-epoch: last = 10.632 s, mean = 10.632 s | Train-step: last = 0.016006 s, mean = 0.022576 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:48:56,318 INFO: [Epoch 6 / Test]: Loss = 0.44461',
#  'colossalai - colossalai - 2022-03-28 01:48:56,322 INFO: [Epoch 6 / Test]: Test-epoch: last = 1.6819 s, mean = 1.6819 s | Test-step: last = 0.0033324 s, mean = 0.021144 s',
#  'colossalai - colossalai - 2022-03-28 01:48:56,326 INFO: [Epoch 6 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:07,058 INFO: [Epoch 7 / Train]: Loss = 0.44876 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:49:07,063 INFO: [Epoch 7 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:07,066 INFO: [Epoch 7 / Train]: Train-epoch: last = 10.54 s, mean = 10.54 s | Train-step: last = 0.016399 s, mean = 0.022514 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:49:08,847 INFO: [Epoch 7 / Test]: Loss = 0.42211',
#  'colossalai - colossalai - 2022-03-28 01:49:08,851 INFO: [Epoch 7 / Test]: Test-epoch: last = 1.6078 s, mean = 1.6078 s | Test-step: last = 0.0028768 s, mean = 0.020207 s',
#  'colossalai - colossalai - 2022-03-28 01:49:08,855 INFO: [Epoch 7 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:19,641 INFO: [Epoch 8 / Train]: Loss = 0.42772 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:49:19,646 INFO: [Epoch 8 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:19,649 INFO: [Epoch 8 / Train]: Train-epoch: last = 10.584 s, mean = 10.584 s | Train-step: last = 0.022443 s, mean = 0.022474 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:49:21,507 INFO: [Epoch 8 / Test]: Loss = 0.4028',
#  'colossalai - colossalai - 2022-03-28 01:49:21,512 INFO: [Epoch 8 / Test]: Test-epoch: last = 1.6785 s, mean = 1.6785 s | Test-step: last = 0.0031247 s, mean = 0.021103 s',
#  'colossalai - colossalai - 2022-03-28 01:49:21,516 INFO: [Epoch 8 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:32,364 INFO: [Epoch 9 / Train]: Loss = 0.4094 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:49:32,370 INFO: [Epoch 9 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:32,373 INFO: [Epoch 9 / Train]: Train-epoch: last = 10.649 s, mean = 10.649 s | Train-step: last = 0.016256 s, mean = 0.022458 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:49:34,294 INFO: [Epoch 9 / Test]: Loss = 0.38579',
#  'colossalai - colossalai - 2022-03-28 01:49:34,298 INFO: [Epoch 9 / Test]: Test-epoch: last = 1.7462 s, mean = 1.7462 s | Test-step: last = 0.0032804 s, mean = 0.021956 s',
#  'colossalai - colossalai - 2022-03-28 01:49:34,303 INFO: [Epoch 9 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:45,611 INFO: [Epoch 10 / Train]: Loss = 0.39332 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:49:45,616 INFO: [Epoch 10 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:45,619 INFO: [Epoch 10 / Train]: Train-epoch: last = 11.114 s, mean = 11.114 s | Train-step: last = 0.017672 s, mean = 0.022535 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:49:47,420 INFO: [Epoch 10 / Test]: Loss = 0.3712',
#  'colossalai - colossalai - 2022-03-28 01:49:47,426 INFO: [Epoch 10 / Test]: Test-epoch: last = 1.6309 s, mean = 1.6309 s | Test-step: last = 0.0034542 s, mean = 0.020507 s',
#  'colossalai - colossalai - 2022-03-28 01:49:47,430 INFO: [Epoch 10 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:58,226 INFO: [Epoch 11 / Train]: Loss = 0.37904 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:49:58,233 INFO: [Epoch 11 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:49:58,236 INFO: [Epoch 11 / Train]: Train-epoch: last = 10.647 s, mean = 10.647 s | Train-step: last = 0.015866 s, mean = 0.022517 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:49:59,990 INFO: [Epoch 11 / Test]: Loss = 0.3577',
#  'colossalai - colossalai - 2022-03-28 01:49:59,994 INFO: [Epoch 11 / Test]: Test-epoch: last = 1.5952 s, mean = 1.5952 s | Test-step: last = 0.0028608 s, mean = 0.020058 s',
#  'colossalai - colossalai - 2022-03-28 01:49:59,998 INFO: [Epoch 11 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:10,367 INFO: [Epoch 12 / Train]: Loss = 0.36629 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:50:10,372 INFO: [Epoch 12 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:10,375 INFO: [Epoch 12 / Train]: Train-epoch: last = 10.171 s, mean = 10.171 s | Train-step: last = 0.015703 s, mean = 0.022423 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:50:12,293 INFO: [Epoch 12 / Test]: Loss = 0.34592',
#  'colossalai - colossalai - 2022-03-28 01:50:12,298 INFO: [Epoch 12 / Test]: Test-epoch: last = 1.743 s, mean = 1.743 s | Test-step: last = 0.0033112 s, mean = 0.021917 s',
#  'colossalai - colossalai - 2022-03-28 01:50:12,303 INFO: [Epoch 12 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:23,162 INFO: [Epoch 13 / Train]: Loss = 0.35469 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:50:23,167 INFO: [Epoch 13 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:23,170 INFO: [Epoch 13 / Train]: Train-epoch: last = 10.697 s, mean = 10.697 s | Train-step: last = 0.015903 s, mean = 0.022424 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:50:25,118 INFO: [Epoch 13 / Test]: Loss = 0.33485',
#  'colossalai - colossalai - 2022-03-28 01:50:25,123 INFO: [Epoch 13 / Test]: Test-epoch: last = 1.7517 s, mean = 1.7517 s | Test-step: last = 0.0030596 s, mean = 0.021997 s',
#  'colossalai - colossalai - 2022-03-28 01:50:25,127 INFO: [Epoch 13 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:36,205 INFO: [Epoch 14 / Train]: Loss = 0.34402 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:50:36,210 INFO: [Epoch 14 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:36,213 INFO: [Epoch 14 / Train]: Train-epoch: last = 10.916 s, mean = 10.916 s | Train-step: last = 0.020627 s, mean = 0.022453 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:50:38,022 INFO: [Epoch 14 / Test]: Loss = 0.325',
#  'colossalai - colossalai - 2022-03-28 01:50:38,027 INFO: [Epoch 14 / Test]: Test-epoch: last = 1.6531 s, mean = 1.6531 s | Test-step: last = 0.0035462 s, mean = 0.02079 s',
#  'colossalai - colossalai - 2022-03-28 01:50:38,031 INFO: [Epoch 14 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:48,861 INFO: [Epoch 15 / Train]: Loss = 0.33429 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:50:48,866 INFO: [Epoch 15 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:50:48,868 INFO: [Epoch 15 / Train]: Train-epoch: last = 10.659 s, mean = 10.659 s | Train-step: last = 0.015367 s, mean = 0.022447 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:50:50,806 INFO: [Epoch 15 / Test]: Loss = 0.31597',
#  'colossalai - colossalai - 2022-03-28 01:50:50,812 INFO: [Epoch 15 / Test]: Test-epoch: last = 1.7797 s, mean = 1.7797 s | Test-step: last = 0.0032218 s, mean = 0.022387 s',
#  'colossalai - colossalai - 2022-03-28 01:50:50,816 INFO: [Epoch 15 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:01,899 INFO: [Epoch 16 / Train]: Loss = 0.32528 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:51:01,905 INFO: [Epoch 16 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:01,908 INFO: [Epoch 16 / Train]: Train-epoch: last = 10.92 s, mean = 10.92 s | Train-step: last = 0.01612 s, mean = 0.022474 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:51:03,743 INFO: [Epoch 16 / Test]: Loss = 0.30737',
#  'colossalai - colossalai - 2022-03-28 01:51:03,747 INFO: [Epoch 16 / Test]: Test-epoch: last = 1.6553 s, mean = 1.6553 s | Test-step: last = 0.0030234 s, mean = 0.020816 s',
#  'colossalai - colossalai - 2022-03-28 01:51:03,751 INFO: [Epoch 16 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:14,630 INFO: [Epoch 17 / Train]: Loss = 0.31696 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:51:14,636 INFO: [Epoch 17 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:14,639 INFO: [Epoch 17 / Train]: Train-epoch: last = 10.695 s, mean = 10.695 s | Train-step: last = 0.015918 s, mean = 0.022471 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:51:16,493 INFO: [Epoch 17 / Test]: Loss = 0.29958',
#  'colossalai - colossalai - 2022-03-28 01:51:16,497 INFO: [Epoch 17 / Test]: Test-epoch: last = 1.6815 s, mean = 1.6815 s | Test-step: last = 0.002893 s, mean = 0.021143 s',
#  'colossalai - colossalai - 2022-03-28 01:51:16,501 INFO: [Epoch 17 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:27,365 INFO: [Epoch 18 / Train]: Loss = 0.30908 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:51:27,371 INFO: [Epoch 18 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:27,374 INFO: [Epoch 18 / Train]: Train-epoch: last = 10.664 s, mean = 10.664 s | Train-step: last = 0.016162 s, mean = 0.022465 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:51:29,183 INFO: [Epoch 18 / Test]: Loss = 0.29222',
#  'colossalai - colossalai - 2022-03-28 01:51:29,188 INFO: [Epoch 18 / Test]: Test-epoch: last = 1.6683 s, mean = 1.6683 s | Test-step: last = 0.0030048 s, mean = 0.020981 s',
#  'colossalai - colossalai - 2022-03-28 01:51:29,196 INFO: [Epoch 18 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:40,334 INFO: [Epoch 19 / Train]: Loss = 0.30165 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:51:40,340 INFO: [Epoch 19 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:40,343 INFO: [Epoch 19 / Train]: Train-epoch: last = 10.982 s, mean = 10.982 s | Train-step: last = 0.01576 s, mean = 0.022494 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:51:42,113 INFO: [Epoch 19 / Test]: Loss = 0.2849',
#  'colossalai - colossalai - 2022-03-28 01:51:42,118 INFO: [Epoch 19 / Test]: Test-epoch: last = 1.6336 s, mean = 1.6336 s | Test-step: last = 0.0031416 s, mean = 0.020536 s',
#  'colossalai - colossalai - 2022-03-28 01:51:42,122 INFO: [Epoch 19 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:53,085 INFO: [Epoch 20 / Train]: Loss = 0.29448 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:51:53,090 INFO: [Epoch 20 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:51:53,093 INFO: [Epoch 20 / Train]: Train-epoch: last = 10.767 s, mean = 10.767 s | Train-step: last = 0.016104 s, mean = 0.022496 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:51:54,952 INFO: [Epoch 20 / Test]: Loss = 0.27812',
#  'colossalai - colossalai - 2022-03-28 01:51:54,958 INFO: [Epoch 20 / Test]: Test-epoch: last = 1.6965 s, mean = 1.6965 s | Test-step: last = 0.0030041 s, mean = 0.021332 s',
#  'colossalai - colossalai - 2022-03-28 01:51:54,962 INFO: [Epoch 20 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:05,693 INFO: [Epoch 21 / Train]: Loss = 0.28767 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:52:05,698 INFO: [Epoch 21 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:05,701 INFO: [Epoch 21 / Train]: Train-epoch: last = 10.579 s, mean = 10.579 s | Train-step: last = 0.016409 s, mean = 0.022481 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:52:07,502 INFO: [Epoch 21 / Test]: Loss = 0.27197',
#  'colossalai - colossalai - 2022-03-28 01:52:07,506 INFO: [Epoch 21 / Test]: Test-epoch: last = 1.6526 s, mean = 1.6526 s | Test-step: last = 0.0028725 s, mean = 0.020778 s',
#  'colossalai - colossalai - 2022-03-28 01:52:07,510 INFO: [Epoch 21 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:18,466 INFO: [Epoch 22 / Train]: Loss = 0.28127 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:52:18,471 INFO: [Epoch 22 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:18,474 INFO: [Epoch 22 / Train]: Train-epoch: last = 10.746 s, mean = 10.746 s | Train-step: last = 0.016124 s, mean = 0.022483 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:52:20,401 INFO: [Epoch 22 / Test]: Loss = 0.26585',
#  'colossalai - colossalai - 2022-03-28 01:52:20,406 INFO: [Epoch 22 / Test]: Test-epoch: last = 1.7589 s, mean = 1.7589 s | Test-step: last = 0.0020773 s, mean = 0.02212 s',
#  'colossalai - colossalai - 2022-03-28 01:52:20,410 INFO: [Epoch 22 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:31,008 INFO: [Epoch 23 / Train]: Loss = 0.27516 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:52:31,013 INFO: [Epoch 23 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:31,016 INFO: [Epoch 23 / Train]: Train-epoch: last = 10.425 s, mean = 10.425 s | Train-step: last = 0.016181 s, mean = 0.022456 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:52:32,892 INFO: [Epoch 23 / Test]: Loss = 0.25961',
#  'colossalai - colossalai - 2022-03-28 01:52:32,896 INFO: [Epoch 23 / Test]: Test-epoch: last = 1.7082 s, mean = 1.7082 s | Test-step: last = 0.0031471 s, mean = 0.021468 s',
#  'colossalai - colossalai - 2022-03-28 01:52:32,900 INFO: [Epoch 23 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:44,177 INFO: [Epoch 24 / Train]: Loss = 0.26917 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:52:44,184 INFO: [Epoch 24 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:44,187 INFO: [Epoch 24 / Train]: Train-epoch: last = 11.115 s, mean = 11.115 s | Train-step: last = 0.01644 s, mean = 0.02249 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:52:46,052 INFO: [Epoch 24 / Test]: Loss = 0.25443',
#  'colossalai - colossalai - 2022-03-28 01:52:46,056 INFO: [Epoch 24 / Test]: Test-epoch: last = 1.721 s, mean = 1.721 s | Test-step: last = 0.0031171 s, mean = 0.021645 s',
#  'colossalai - colossalai - 2022-03-28 01:52:46,060 INFO: [Epoch 24 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:56,870 INFO: [Epoch 25 / Train]: Loss = 0.26357 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:52:56,876 INFO: [Epoch 25 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:52:56,879 INFO: [Epoch 25 / Train]: Train-epoch: last = 10.611 s, mean = 10.611 s | Train-step: last = 0.01647 s, mean = 0.02248 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:52:58,721 INFO: [Epoch 25 / Test]: Loss = 0.249',
#  'colossalai - colossalai - 2022-03-28 01:52:58,726 INFO: [Epoch 25 / Test]: Test-epoch: last = 1.6632 s, mean = 1.6632 s | Test-step: last = 0.0032184 s, mean = 0.020914 s',
#  'colossalai - colossalai - 2022-03-28 01:52:58,730 INFO: [Epoch 25 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:09,480 INFO: [Epoch 26 / Train]: Loss = 0.25796 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:53:09,485 INFO: [Epoch 26 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:09,488 INFO: [Epoch 26 / Train]: Train-epoch: last = 10.564 s, mean = 10.564 s | Train-step: last = 0.016079 s, mean = 0.022467 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:53:11,387 INFO: [Epoch 26 / Test]: Loss = 0.24348',
#  'colossalai - colossalai - 2022-03-28 01:53:11,391 INFO: [Epoch 26 / Test]: Test-epoch: last = 1.7208 s, mean = 1.7208 s | Test-step: last = 0.0031765 s, mean = 0.021638 s',
#  'colossalai - colossalai - 2022-03-28 01:53:11,395 INFO: [Epoch 26 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:22,025 INFO: [Epoch 27 / Train]: Loss = 0.25267 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:53:22,031 INFO: [Epoch 27 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:22,035 INFO: [Epoch 27 / Train]: Train-epoch: last = 10.444 s, mean = 10.444 s | Train-step: last = 0.016221 s, mean = 0.022445 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:53:23,929 INFO: [Epoch 27 / Test]: Loss = 0.23841',
#  'colossalai - colossalai - 2022-03-28 01:53:23,933 INFO: [Epoch 27 / Test]: Test-epoch: last = 1.7208 s, mean = 1.7208 s | Test-step: last = 0.0031016 s, mean = 0.021636 s',
#  'colossalai - colossalai - 2022-03-28 01:53:23,937 INFO: [Epoch 27 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:34,741 INFO: [Epoch 28 / Train]: Loss = 0.24753 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:53:34,746 INFO: [Epoch 28 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:34,749 INFO: [Epoch 28 / Train]: Train-epoch: last = 10.632 s, mean = 10.632 s | Train-step: last = 0.016324 s, mean = 0.022439 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:53:36,824 INFO: [Epoch 28 / Test]: Loss = 0.23371',
#  'colossalai - colossalai - 2022-03-28 01:53:36,828 INFO: [Epoch 28 / Test]: Test-epoch: last = 1.892 s, mean = 1.892 s | Test-step: last = 0.0035608 s, mean = 0.023808 s',
#  'colossalai - colossalai - 2022-03-28 01:53:36,832 INFO: [Epoch 28 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:47,320 INFO: [Epoch 29 / Train]: Loss = 0.24267 | LR = 1e-05',
#  'colossalai - colossalai - 2022-03-28 01:53:47,326 INFO: [Epoch 29 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:47,329 INFO: [Epoch 29 / Train]: Train-epoch: last = 10.302 s, mean = 10.302 s | Train-step: last = 0.015491 s, mean = 0.022411 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:53:49,424 INFO: [Epoch 29 / Test]: Loss = 0.22936',
#  'colossalai - colossalai - 2022-03-28 01:53:49,428 INFO: [Epoch 29 / Test]: Test-epoch: last = 1.9286 s, mean = 1.9286 s | Test-step: last = 0.0032938 s, mean = 0.024272 s',
#  'colossalai - colossalai - 2022-03-28 01:53:49,432 INFO: [Epoch 29 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:53:49,593 INFO:',
#  '========== Your Config ========',
#  "{'BATCH_SIZE': 128, 'NUM_EPOCHS': 30}",
#  '================================',
#  '',
#  'colossalai - colossalai - 2022-03-28 01:53:49,596 INFO: cuDNN benchmark = True, deterministic = False',
#  'colossalai - colossalai - 2022-03-28 01:53:49,599 WARNING: Initializing an non ZeRO model with optimizer class',
#  'colossalai - colossalai - 2022-03-28 01:53:49,601 WARNING: No PyTorch DDP or gradient handler is set up, please make sure you do not need to all-reduce the gradients after a training step.',
#  'colossalai - colossalai - 2022-03-28 01:53:49,605 INFO: Using LossHook for training, priority = 0',
#  'colossalai - colossalai - 2022-03-28 01:53:49,607 INFO: Using LRSchedulerHook for training, priority = 1',
#  'colossalai - colossalai - 2022-03-28 01:53:49,609 INFO: Using LogMetricByEpochHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:53:49,612 INFO: Using LogMemoryByEpochHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:53:49,614 INFO: Using LogTimingByEpochHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:53:49,616 INFO: Using TensorboardHook for training, priority = 10',
#  'colossalai - colossalai - 2022-03-28 01:53:49,619 INFO: Lower value means higher priority for calling hook function',
#  'colossalai - colossalai - 2022-03-28 01:53:49,622 INFO: Before-train: GPU: allocated 0.95 MB, max allocated 1.67 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:00,449 INFO: [Epoch 0 / Train]: Loss = 0.57978 | LR = 0.00068961',
#  'colossalai - colossalai - 2022-03-28 01:54:00,455 INFO: [Epoch 0 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:00,458 INFO: [Epoch 0 / Train]: Train-epoch: last = 10.728 s, mean = 10.728 s | Train-step: last = 0.016159 s, mean = 0.022468 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:54:02,363 INFO: [Epoch 0 / Test]: Loss = 0.20451',
#  'colossalai - colossalai - 2022-03-28 01:54:02,368 INFO: [Epoch 0 / Test]: Test-epoch: last = 1.7436 s, mean = 1.7436 s | Test-step: last = 0.0031276 s, mean = 0.021921 s',
#  'colossalai - colossalai - 2022-03-28 01:54:02,372 INFO: [Epoch 0 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:13,140 INFO: [Epoch 1 / Train]: Loss = 0.15392 | LR = 0.0015235',
#  'colossalai - colossalai - 2022-03-28 01:54:13,146 INFO: [Epoch 1 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:13,149 INFO: [Epoch 1 / Train]: Train-epoch: last = 10.586 s, mean = 10.586 s | Train-step: last = 0.0159 s, mean = 0.022309 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:54:15,087 INFO: [Epoch 1 / Test]: Loss = 0.096476',
#  'colossalai - colossalai - 2022-03-28 01:54:15,093 INFO: [Epoch 1 / Test]: Test-epoch: last = 1.7654 s, mean = 1.7654 s | Test-step: last = 0.0030558 s, mean = 0.022197 s',
#  'colossalai - colossalai - 2022-03-28 01:54:15,097 INFO: [Epoch 1 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:25,746 INFO: [Epoch 2 / Train]: Loss = 0.09608 | LR = 0.002801',
#  'colossalai - colossalai - 2022-03-28 01:54:25,752 INFO: [Epoch 2 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:25,754 INFO: [Epoch 2 / Train]: Train-epoch: last = 10.469 s, mean = 10.469 s | Train-step: last = 0.015702 s, mean = 0.022183 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:54:27,632 INFO: [Epoch 2 / Test]: Loss = 0.090193',
#  'colossalai - colossalai - 2022-03-28 01:54:27,636 INFO: [Epoch 2 / Test]: Test-epoch: last = 1.7075 s, mean = 1.7075 s | Test-step: last = 0.0030758 s, mean = 0.021475 s',
#  'colossalai - colossalai - 2022-03-28 01:54:27,640 INFO: [Epoch 2 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:38,268 INFO: [Epoch 3 / Train]: Loss = 0.082091 | LR = 0.0043681',
#  'colossalai - colossalai - 2022-03-28 01:54:38,273 INFO: [Epoch 3 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:38,276 INFO: [Epoch 3 / Train]: Train-epoch: last = 10.449 s, mean = 10.449 s | Train-step: last = 0.015859 s, mean = 0.022108 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:54:40,205 INFO: [Epoch 3 / Test]: Loss = 0.094879',
#  'colossalai - colossalai - 2022-03-28 01:54:40,209 INFO: [Epoch 3 / Test]: Test-epoch: last = 1.748 s, mean = 1.748 s | Test-step: last = 0.0032651 s, mean = 0.021985 s',
#  'colossalai - colossalai - 2022-03-28 01:54:40,213 INFO: [Epoch 3 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:50,667 INFO: [Epoch 4 / Train]: Loss = 0.072772 | LR = 0.0060355',
#  'colossalai - colossalai - 2022-03-28 01:54:50,672 INFO: [Epoch 4 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:54:50,679 INFO: [Epoch 4 / Train]: Train-epoch: last = 10.279 s, mean = 10.279 s | Train-step: last = 0.015559 s, mean = 0.02199 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:54:52,738 INFO: [Epoch 4 / Test]: Loss = 0.067879',
#  'colossalai - colossalai - 2022-03-28 01:54:52,742 INFO: [Epoch 4 / Test]: Test-epoch: last = 1.8863 s, mean = 1.8863 s | Test-step: last = 0.0032792 s, mean = 0.023723 s',
#  'colossalai - colossalai - 2022-03-28 01:54:52,746 INFO: [Epoch 4 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:03,658 INFO: [Epoch 5 / Train]: Loss = 0.076892 | LR = 0.0076021',
#  'colossalai - colossalai - 2022-03-28 01:55:03,664 INFO: [Epoch 5 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:03,667 INFO: [Epoch 5 / Train]: Train-epoch: last = 10.74 s, mean = 10.74 s | Train-step: last = 0.016504 s, mean = 0.022074 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:55:05,612 INFO: [Epoch 5 / Test]: Loss = 0.075465',
#  'colossalai - colossalai - 2022-03-28 01:55:05,616 INFO: [Epoch 5 / Test]: Test-epoch: last = 1.7765 s, mean = 1.7765 s | Test-step: last = 0.003319 s, mean = 0.022347 s',
#  'colossalai - colossalai - 2022-03-28 01:55:05,620 INFO: [Epoch 5 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:16,189 INFO: [Epoch 6 / Train]: Loss = 0.081281 | LR = 0.0088788',
#  'colossalai - colossalai - 2022-03-28 01:55:16,195 INFO: [Epoch 6 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:16,198 INFO: [Epoch 6 / Train]: Train-epoch: last = 10.395 s, mean = 10.395 s | Train-step: last = 0.01612 s, mean = 0.022031 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:55:18,066 INFO: [Epoch 6 / Test]: Loss = 0.095826',
#  'colossalai - colossalai - 2022-03-28 01:55:18,070 INFO: [Epoch 6 / Test]: Test-epoch: last = 1.6955 s, mean = 1.6955 s | Test-step: last = 0.0029917 s, mean = 0.021318 s',
#  'colossalai - colossalai - 2022-03-28 01:55:18,074 INFO: [Epoch 6 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:28,860 INFO: [Epoch 7 / Train]: Loss = 0.088351 | LR = 0.0097116',
#  'colossalai - colossalai - 2022-03-28 01:55:28,868 INFO: [Epoch 7 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:28,873 INFO: [Epoch 7 / Train]: Train-epoch: last = 10.613 s, mean = 10.613 s | Train-step: last = 0.015721 s, mean = 0.02205 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:55:30,792 INFO: [Epoch 7 / Test]: Loss = 0.10623',
#  'colossalai - colossalai - 2022-03-28 01:55:30,797 INFO: [Epoch 7 / Test]: Test-epoch: last = 1.7572 s, mean = 1.7572 s | Test-step: last = 0.0032325 s, mean = 0.022096 s',
#  'colossalai - colossalai - 2022-03-28 01:55:30,801 INFO: [Epoch 7 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:41,803 INFO: [Epoch 8 / Train]: Loss = 0.090981 | LR = 0.01',
#  'colossalai - colossalai - 2022-03-28 01:55:41,809 INFO: [Epoch 8 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:41,811 INFO: [Epoch 8 / Train]: Train-epoch: last = 10.821 s, mean = 10.821 s | Train-step: last = 0.016018 s, mean = 0.022121 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:55:43,696 INFO: [Epoch 8 / Test]: Loss = 0.094149',
#  'colossalai - colossalai - 2022-03-28 01:55:43,701 INFO: [Epoch 8 / Test]: Test-epoch: last = 1.7071 s, mean = 1.7071 s | Test-step: last = 0.0037022 s, mean = 0.021462 s',
#  'colossalai - colossalai - 2022-03-28 01:55:43,705 INFO: [Epoch 8 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:54,690 INFO: [Epoch 9 / Train]: Loss = 0.08928 | LR = 0.0099439',
#  'colossalai - colossalai - 2022-03-28 01:55:54,696 INFO: [Epoch 9 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:55:54,699 INFO: [Epoch 9 / Train]: Train-epoch: last = 10.809 s, mean = 10.809 s | Train-step: last = 0.015922 s, mean = 0.022173 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:55:56,782 INFO: [Epoch 9 / Test]: Loss = 0.080141',
#  'colossalai - colossalai - 2022-03-28 01:55:56,789 INFO: [Epoch 9 / Test]: Test-epoch: last = 1.9009 s, mean = 1.9009 s | Test-step: last = 0.0035141 s, mean = 0.023919 s',
#  'colossalai - colossalai - 2022-03-28 01:55:56,793 INFO: [Epoch 9 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:07,370 INFO: [Epoch 10 / Train]: Loss = 0.083386 | LR = 0.0097774',
#  'colossalai - colossalai - 2022-03-28 01:56:07,376 INFO: [Epoch 10 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:07,379 INFO: [Epoch 10 / Train]: Train-epoch: last = 10.394 s, mean = 10.394 s | Train-step: last = 0.015769 s, mean = 0.022136 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:56:09,475 INFO: [Epoch 10 / Test]: Loss = 0.080301',
#  'colossalai - colossalai - 2022-03-28 01:56:09,479 INFO: [Epoch 10 / Test]: Test-epoch: last = 1.9281 s, mean = 1.9281 s | Test-step: last = 0.003386 s, mean = 0.024268 s',
#  'colossalai - colossalai - 2022-03-28 01:56:09,483 INFO: [Epoch 10 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:20,376 INFO: [Epoch 11 / Train]: Loss = 0.078754 | LR = 0.0095042',
#  'colossalai - colossalai - 2022-03-28 01:56:20,381 INFO: [Epoch 11 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:20,384 INFO: [Epoch 11 / Train]: Train-epoch: last = 10.712 s, mean = 10.712 s | Train-step: last = 0.021212 s, mean = 0.022163 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:56:22,155 INFO: [Epoch 11 / Test]: Loss = 0.087106',
#  'colossalai - colossalai - 2022-03-28 01:56:22,159 INFO: [Epoch 11 / Test]: Test-epoch: last = 1.6109 s, mean = 1.6109 s | Test-step: last = 0.0065339 s, mean = 0.02026 s',
#  'colossalai - colossalai - 2022-03-28 01:56:22,163 INFO: [Epoch 11 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:33,084 INFO: [Epoch 12 / Train]: Loss = 0.079898 | LR = 0.0091303',
#  'colossalai - colossalai - 2022-03-28 01:56:33,089 INFO: [Epoch 12 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:33,092 INFO: [Epoch 12 / Train]: Train-epoch: last = 10.734 s, mean = 10.734 s | Train-step: last = 0.016127 s, mean = 0.022189 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:56:34,897 INFO: [Epoch 12 / Test]: Loss = 0.081714',
#  'colossalai - colossalai - 2022-03-28 01:56:34,901 INFO: [Epoch 12 / Test]: Test-epoch: last = 1.6377 s, mean = 1.6377 s | Test-step: last = 0.003073 s, mean = 0.020592 s',
#  'colossalai - colossalai - 2022-03-28 01:56:34,905 INFO: [Epoch 12 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:45,954 INFO: [Epoch 13 / Train]: Loss = 0.075187 | LR = 0.0086642',
#  'colossalai - colossalai - 2022-03-28 01:56:45,959 INFO: [Epoch 13 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:45,962 INFO: [Epoch 13 / Train]: Train-epoch: last = 10.866 s, mean = 10.866 s | Train-step: last = 0.016034 s, mean = 0.022231 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:56:47,908 INFO: [Epoch 13 / Test]: Loss = 0.071151',
#  'colossalai - colossalai - 2022-03-28 01:56:47,913 INFO: [Epoch 13 / Test]: Test-epoch: last = 1.7695 s, mean = 1.7695 s | Test-step: last = 0.0029666 s, mean = 0.022256 s',
#  'colossalai - colossalai - 2022-03-28 01:56:47,917 INFO: [Epoch 13 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:58,867 INFO: [Epoch 14 / Train]: Loss = 0.064624 | LR = 0.0081162',
#  'colossalai - colossalai - 2022-03-28 01:56:58,874 INFO: [Epoch 14 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:56:58,877 INFO: [Epoch 14 / Train]: Train-epoch: last = 10.719 s, mean = 10.719 s | Train-step: last = 0.017882 s, mean = 0.022246 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:57:00,787 INFO: [Epoch 14 / Test]: Loss = 0.072627',
#  'colossalai - colossalai - 2022-03-28 01:57:00,791 INFO: [Epoch 14 / Test]: Test-epoch: last = 1.7289 s, mean = 1.7289 s | Test-step: last = 0.0030856 s, mean = 0.021741 s',
#  'colossalai - colossalai - 2022-03-28 01:57:00,795 INFO: [Epoch 14 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:11,627 INFO: [Epoch 15 / Train]: Loss = 0.064762 | LR = 0.0074986',
#  'colossalai - colossalai - 2022-03-28 01:57:11,632 INFO: [Epoch 15 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:11,635 INFO: [Epoch 15 / Train]: Train-epoch: last = 10.676 s, mean = 10.676 s | Train-step: last = 0.01621 s, mean = 0.022253 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:57:13,425 INFO: [Epoch 15 / Test]: Loss = 0.068938',
#  'colossalai - colossalai - 2022-03-28 01:57:13,429 INFO: [Epoch 15 / Test]: Test-epoch: last = 1.6149 s, mean = 1.6149 s | Test-step: last = 0.002903 s, mean = 0.020305 s',
#  'colossalai - colossalai - 2022-03-28 01:57:13,434 INFO: [Epoch 15 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:24,027 INFO: [Epoch 16 / Train]: Loss = 0.057084 | LR = 0.0068252',
#  'colossalai - colossalai - 2022-03-28 01:57:24,033 INFO: [Epoch 16 / Train]: GPU: allocated 5.66 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:24,036 INFO: [Epoch 16 / Train]: Train-epoch: last = 10.448 s, mean = 10.448 s | Train-step: last = 0.01532 s, mean = 0.022231 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:57:25,855 INFO: [Epoch 16 / Test]: Loss = 0.060576',
#  'colossalai - colossalai - 2022-03-28 01:57:25,859 INFO: [Epoch 16 / Test]: Test-epoch: last = 1.6528 s, mean = 1.6528 s | Test-step: last = 0.0029209 s, mean = 0.020783 s',
#  'colossalai - colossalai - 2022-03-28 01:57:25,864 INFO: [Epoch 16 / Test]: GPU: allocated 1.67 MB, max allocated 6.77 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:37,020 INFO: [Epoch 17 / Train]: Loss = 0.055039 | LR = 0.0061111',
#  'colossalai - colossalai - 2022-03-28 01:57:37,025 INFO: [Epoch 17 / Train]: GPU: allocated 4.94 MB, max allocated 52.26 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:37,028 INFO: [Epoch 17 / Train]: Train-epoch: last = 10.945 s, mean = 10.945 s | Train-step: last = 0.01589 s, mean = 0.02227 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:57:38,856 INFO: [Epoch 17 / Test]: Loss = 0.059301',
#  'colossalai - colossalai - 2022-03-28 01:57:38,860 INFO: [Epoch 17 / Test]: Test-epoch: last = 1.6581 s, mean = 1.6581 s | Test-step: last = 0.0023029 s, mean = 0.020856 s',
#  'colossalai - colossalai - 2022-03-28 01:57:38,864 INFO: [Epoch 17 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:49,504 INFO: [Epoch 18 / Train]: Loss = 0.05134 | LR = 0.0053721',
#  'colossalai - colossalai - 2022-03-28 01:57:49,511 INFO: [Epoch 18 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:57:49,513 INFO: [Epoch 18 / Train]: Train-epoch: last = 10.482 s, mean = 10.482 s | Train-step: last = 0.015725 s, mean = 0.022253 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:57:51,349 INFO: [Epoch 18 / Test]: Loss = 0.060952',
#  'colossalai - colossalai - 2022-03-28 01:57:51,354 INFO: [Epoch 18 / Test]: Test-epoch: last = 1.6595 s, mean = 1.6595 s | Test-step: last = 0.0031326 s, mean = 0.020868 s',
#  'colossalai - colossalai - 2022-03-28 01:57:51,358 INFO: [Epoch 18 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:01,920 INFO: [Epoch 19 / Train]: Loss = 0.042504 | LR = 0.0046248',
#  'colossalai - colossalai - 2022-03-28 01:58:01,925 INFO: [Epoch 19 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:01,928 INFO: [Epoch 19 / Train]: Train-epoch: last = 10.404 s, mean = 10.404 s | Train-step: last = 0.015696 s, mean = 0.02223 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:58:03,737 INFO: [Epoch 19 / Test]: Loss = 0.060646',
#  'colossalai - colossalai - 2022-03-28 01:58:03,741 INFO: [Epoch 19 / Test]: Test-epoch: last = 1.658 s, mean = 1.658 s | Test-step: last = 0.0029647 s, mean = 0.020851 s',
#  'colossalai - colossalai - 2022-03-28 01:58:03,745 INFO: [Epoch 19 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:14,266 INFO: [Epoch 20 / Train]: Loss = 0.034806 | LR = 0.0038859',
#  'colossalai - colossalai - 2022-03-28 01:58:14,272 INFO: [Epoch 20 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:14,275 INFO: [Epoch 20 / Train]: Train-epoch: last = 10.387 s, mean = 10.387 s | Train-step: last = 0.016239 s, mean = 0.022208 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:58:16,160 INFO: [Epoch 20 / Test]: Loss = 0.0537',
#  'colossalai - colossalai - 2022-03-28 01:58:16,164 INFO: [Epoch 20 / Test]: Test-epoch: last = 1.722 s, mean = 1.722 s | Test-step: last = 0.0032685 s, mean = 0.021661 s',
#  'colossalai - colossalai - 2022-03-28 01:58:16,168 INFO: [Epoch 20 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:26,859 INFO: [Epoch 21 / Train]: Loss = 0.029979 | LR = 0.0031718',
#  'colossalai - colossalai - 2022-03-28 01:58:26,864 INFO: [Epoch 21 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:26,867 INFO: [Epoch 21 / Train]: Train-epoch: last = 10.499 s, mean = 10.499 s | Train-step: last = 0.018157 s, mean = 0.022198 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:58:28,775 INFO: [Epoch 21 / Test]: Loss = 0.054246',
#  'colossalai - colossalai - 2022-03-28 01:58:28,780 INFO: [Epoch 21 / Test]: Test-epoch: last = 1.7367 s, mean = 1.7367 s | Test-step: last = 0.0032291 s, mean = 0.021842 s',
#  'colossalai - colossalai - 2022-03-28 01:58:28,784 INFO: [Epoch 21 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:39,724 INFO: [Epoch 22 / Train]: Loss = 0.022276 | LR = 0.0024986',
#  'colossalai - colossalai - 2022-03-28 01:58:39,729 INFO: [Epoch 22 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:39,732 INFO: [Epoch 22 / Train]: Train-epoch: last = 10.762 s, mean = 10.762 s | Train-step: last = 0.015949 s, mean = 0.022214 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:58:41,614 INFO: [Epoch 22 / Test]: Loss = 0.049043',
#  'colossalai - colossalai - 2022-03-28 01:58:41,619 INFO: [Epoch 22 / Test]: Test-epoch: last = 1.709 s, mean = 1.709 s | Test-step: last = 0.0030909 s, mean = 0.021492 s',
#  'colossalai - colossalai - 2022-03-28 01:58:41,623 INFO: [Epoch 22 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:52,615 INFO: [Epoch 23 / Train]: Loss = 0.016104 | LR = 0.0018813',
#  'colossalai - colossalai - 2022-03-28 01:58:52,621 INFO: [Epoch 23 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:58:52,624 INFO: [Epoch 23 / Train]: Train-epoch: last = 10.834 s, mean = 10.834 s | Train-step: last = 0.016647 s, mean = 0.022234 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:58:54,726 INFO: [Epoch 23 / Test]: Loss = 0.051445',
#  'colossalai - colossalai - 2022-03-28 01:58:54,730 INFO: [Epoch 23 / Test]: Test-epoch: last = 1.925 s, mean = 1.925 s | Test-step: last = 0.0029762 s, mean = 0.02422 s',
#  'colossalai - colossalai - 2022-03-28 01:58:54,735 INFO: [Epoch 23 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:05,958 INFO: [Epoch 24 / Train]: Loss = 0.011806 | LR = 0.0013337',
#  'colossalai - colossalai - 2022-03-28 01:59:05,964 INFO: [Epoch 24 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:05,967 INFO: [Epoch 24 / Train]: Train-epoch: last = 11.066 s, mean = 11.066 s | Train-step: last = 0.015982 s, mean = 0.022273 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:59:07,899 INFO: [Epoch 24 / Test]: Loss = 0.050182',
#  'colossalai - colossalai - 2022-03-28 01:59:07,904 INFO: [Epoch 24 / Test]: Test-epoch: last = 1.7775 s, mean = 1.7775 s | Test-step: last = 0.0039644 s, mean = 0.022366 s',
#  'colossalai - colossalai - 2022-03-28 01:59:07,908 INFO: [Epoch 24 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:18,358 INFO: [Epoch 25 / Train]: Loss = 0.0078722 | LR = 0.00086794',
#  'colossalai - colossalai - 2022-03-28 01:59:18,366 INFO: [Epoch 25 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:18,371 INFO: [Epoch 25 / Train]: Train-epoch: last = 10.299 s, mean = 10.299 s | Train-step: last = 0.015442 s, mean = 0.022243 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:59:20,326 INFO: [Epoch 25 / Test]: Loss = 0.049912',
#  'colossalai - colossalai - 2022-03-28 01:59:20,332 INFO: [Epoch 25 / Test]: Test-epoch: last = 1.7577 s, mean = 1.7577 s | Test-step: last = 0.0032215 s, mean = 0.022105 s',
#  'colossalai - colossalai - 2022-03-28 01:59:20,338 INFO: [Epoch 25 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:31,205 INFO: [Epoch 26 / Train]: Loss = 0.0052612 | LR = 0.0004945',
#  'colossalai - colossalai - 2022-03-28 01:59:31,210 INFO: [Epoch 26 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:31,213 INFO: [Epoch 26 / Train]: Train-epoch: last = 10.693 s, mean = 10.693 s | Train-step: last = 0.019361 s, mean = 0.022249 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:59:33,009 INFO: [Epoch 26 / Test]: Loss = 0.048587',
#  'colossalai - colossalai - 2022-03-28 01:59:33,013 INFO: [Epoch 26 / Test]: Test-epoch: last = 1.6333 s, mean = 1.6333 s | Test-step: last = 0.0029829 s, mean = 0.020531 s',
#  'colossalai - colossalai - 2022-03-28 01:59:33,018 INFO: [Epoch 26 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:43,786 INFO: [Epoch 27 / Train]: Loss = 0.0042468 | LR = 0.00022171',
#  'colossalai - colossalai - 2022-03-28 01:59:43,791 INFO: [Epoch 27 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:43,794 INFO: [Epoch 27 / Train]: Train-epoch: last = 10.631 s, mean = 10.631 s | Train-step: last = 0.01611 s, mean = 0.02225 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:59:45,720 INFO: [Epoch 27 / Test]: Loss = 0.048707',
#  'colossalai - colossalai - 2022-03-28 01:59:45,725 INFO: [Epoch 27 / Test]: Test-epoch: last = 1.7587 s, mean = 1.7587 s | Test-step: last = 0.0031848 s, mean = 0.022115 s',
#  'colossalai - colossalai - 2022-03-28 01:59:45,729 INFO: [Epoch 27 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:56,394 INFO: [Epoch 28 / Train]: Loss = 0.0038746 | LR = 5.5648e-05',
#  'colossalai - colossalai - 2022-03-28 01:59:56,400 INFO: [Epoch 28 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 01:59:56,404 INFO: [Epoch 28 / Train]: Train-epoch: last = 10.485 s, mean = 10.485 s | Train-step: last = 0.01661 s, mean = 0.02224 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 01:59:58,321 INFO: [Epoch 28 / Test]: Loss = 0.048646',
#  'colossalai - colossalai - 2022-03-28 01:59:58,325 INFO: [Epoch 28 / Test]: Test-epoch: last = 1.7369 s, mean = 1.7369 s | Test-step: last = 0.0034733 s, mean = 0.021848 s',
#  'colossalai - colossalai - 2022-03-28 01:59:58,329 INFO: [Epoch 28 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 02:00:08,895 INFO: [Epoch 29 / Train]: Loss = 0.0037249 | LR = 4.0254e-08',
#  'colossalai - colossalai - 2022-03-28 02:00:08,901 INFO: [Epoch 29 / Train]: GPU: allocated 4.94 MB, max allocated 51.54 MB, cached: 70.0 MB, max cached: 70.0 MB',
#  'colossalai - colossalai - 2022-03-28 02:00:08,904 INFO: [Epoch 29 / Train]: Train-epoch: last = 10.388 s, mean = 10.388 s | Train-step: last = 0.015865 s, mean = 0.022223 s | #steps/epoch = 469',
#  'colossalai - colossalai - 2022-03-28 02:00:10,783 INFO: [Epoch 29 / Test]: Loss = 0.048594',
#  'colossalai - colossalai - 2022-03-28 02:00:10,787 INFO: [Epoch 29 / Test]: Test-epoch: last = 1.7101 s, mean = 1.7101 s | Test-step: last = 0.0032101 s, mean = 0.02151 s',
#  'colossalai - colossalai - 2022-03-28 02:00:10,791 INFO: [Epoch 29 / Test]: GPU: allocated 0.96 MB, max allocated 6.05 MB, cached: 70.0 MB, max cached: 70.0 MB']

# %%
data = []

lines = open_list(txt_file_path)
for line in lines:
    loss_value = re.search(" Loss = ([\d|.]*)", line)
    if loss_value is not None:
        loss_value = loss_value.group(1)
    else:
        continue
    
    epoch = re.search("Epoch ([\d]*) ", line).group(1)
    split = re.search("/ (.*)]: ", line).group(1)

    data.append([version, loss_value, epoch, split])

data = pd.DataFrame(data,columns=['version','loss','epoch','split'])
data['loss'] = data['loss'].astype(float)
data['epoch'] = data['epoch'].astype(int)
data = data.sort_values(by=['version','epoch','split']).reset_index(drop=True)
data
# Out:
#                 version      loss  epoch  split
# 0    adamw_lambda_0.001  0.711490      0   Test
# 1    adamw_lambda_0.001  0.204510      0   Test
# 2    adamw_lambda_0.001  0.833190      0  Train
# 3    adamw_lambda_0.001  0.579780      0  Train
# 4    adamw_lambda_0.001  0.641630      1   Test
# ..                  ...       ...    ...    ...
# 115  adamw_lambda_0.001  0.003875     28  Train
# 116  adamw_lambda_0.001  0.229360     29   Test
# 117  adamw_lambda_0.001  0.048594     29   Test
# 118  adamw_lambda_0.001  0.242670     29  Train
# 119  adamw_lambda_0.001  0.003725     29  Train
#
# [120 rows x 4 columns]

# %%
# data.to_csv('tmp.csv')

# %%
# Run all

# Propose several learning rates for real training.
learning_rates = [0.1,0.05,0.001]
# Choose one optimizer 
optimizer_methods = ['sgd','adamw']
# Choose two learning rate scheduling method 
scheduler_methods = ['lambda','multistep','onecycle']

# Loop
data = []
for learning_rate in learning_rates:
    for optimizer_method in optimizer_methods:
        for scheduler_method in scheduler_methods:
            version = f'{optimizer_method}_{scheduler_method}_{learning_rate}'
            txt_file_path = os.path.join('tb_logs',version,'rank_0.log')
            lines = open_list(txt_file_path)
            for line in lines:
                loss_value = re.search(" Loss = ([\d|.]*)", line)
                if loss_value is not None:
                    loss_value = loss_value.group(1)
                else:
                    continue

                epoch = re.search("Epoch ([\d]*) ", line).group(1)
                split = re.search("/ (.*)]: ", line).group(1)

                data.append([optimizer_method, scheduler_method, learning_rate, loss_value, epoch, split])

data = pd.DataFrame(data,columns=['optimizer','scheduler','learning_rate','loss','epoch','split'])
data['loss'] = data['loss'].astype(float)
data['learning_rate'] = data['learning_rate'].astype(float)
data['epoch'] = data['epoch'].astype(int)
data = data.sort_values(by=['optimizer','scheduler','learning_rate','epoch','split']).reset_index(drop=True)
data
# Out:
#      optimizer scheduler  learning_rate      loss  epoch  split
# 0        adamw    lambda          0.001  0.711490      0   Test
# 1        adamw    lambda          0.001  0.204510      0   Test
# 2        adamw    lambda          0.001  0.833190      0  Train
# 3        adamw    lambda          0.001  0.579780      0  Train
# 4        adamw    lambda          0.001  0.641630      1   Test
# ...        ...       ...            ...       ...    ...    ...
# 9175       sgd  onecycle          0.100  2.271900     29  Train
# 9176       sgd  onecycle          0.100  0.027415     29  Train
# 9177       sgd  onecycle          0.100  0.089330     29  Train
# 9178       sgd  onecycle          0.100  0.242670     29  Train
# 9179       sgd  onecycle          0.100  0.003725     29  Train
#
# [9180 rows x 6 columns]

# %%
data.to_csv('tb_logs/results.csv',index=False)
